# %%
import matplotlib.pyplot as plot
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import svm
import numpy as np
import pandas as pd
from sklearn import preprocessing
from pandas import DataFrame
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from sklearn.model_selection import KFold
from sklearn.metrics import roc_curve
from sklearn.metrics import confusion_matrix
from gplearn import genetic
from gplearn.genetic import SymbolicTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler, SMOTE
from collections import Counter
from sklearn.model_selection import train_test_split
import sklearn.ensemble as ensemble  # ensemble learning: 集成学习
from sklearn.model_selection import GridSearchCV
import sklearn.metrics as metrics
import matplotlib.pyplot as plt

# %%
# dataset= r'data15-00.csv'
# data=pd.DataFrame(pd.read_csv(dataset))
# data

data = pd.read_excel('data1500.xlsx')
data
# Out:
#               a1   a2   a3   a4 a1_coefficients a2_coefficients  \
# 0          (Ada)   FA  NaN  NaN               2               2
# 1     (AVA) | MA  NaN  NaN  NaN           2 | 1             NaN
# 2          (BdA)  NaN  NaN  NaN               1             NaN
# 3          (BEA)   MA  NaN  NaN             0.5               3
# 4          (BEA)   Cs   FA   MA             0.5            0.15
# ...          ...  ...  ...  ...             ...             ...
# 7196     MA | MA  NaN  NaN  NaN           1 | 1             NaN
# 7197     MA | MA  NaN  NaN  NaN           1 | 1             NaN
# 7198     MA | MA  NaN  NaN  NaN           1 | 1             NaN
# 7199     MA | MA  NaN  NaN  NaN           1 | 1             NaN
# 7200          PA  NaN  NaN  NaN               2             NaN
#
#      a3_coefficients  a4_coefficients       b1   b2  ... c2_coefficients  \
# 0                NaN              NaN       Pb  NaN  ...             NaN
# 1                NaN              NaN  Pb | Pb  NaN  ...             NaN
# 2                NaN              NaN       Pb  NaN  ...             NaN
# 3                NaN              NaN       Pb  NaN  ...             NaN
# 4               2.36             0.48       Pb  NaN  ...            0.83
# ...              ...              ...      ...  ...  ...             ...
# 7196             NaN              NaN  Pb | Pb  NaN  ...             NaN
# 7197             NaN              NaN  Pb | Pb  NaN  ...             NaN
# 7198             NaN              NaN  Pb | Pb  NaN  ...             NaN
# 7199             NaN              NaN  Pb | Pb  NaN  ...             NaN
# 7200             NaN              NaN       Pb  NaN  ...             NaN
#
#       c3_coefficients Perovskite_deposition_thermal_annealing_temperature  \
# 0                 NaN                                       120.0; 150.0
# 1                 NaN                                                100
# 2                 NaN                                                 90
# 3                 NaN                                                100
# 4                 NaN                                                100
# ...               ...                                                ...
# 7196              NaN                                         100 >> 100
# 7197              NaN                                          25 >> 100
# 7198              NaN                                         100 >> 100
# 7199              NaN                                         100 >> 100
# 7200              NaN                                                105
#
#      Perovskite_deposition_thermal_annealing_time ETL_stack_sequence  \
# 0                                      20.0; 10.0   TiO2-c | TiO2-mp
# 1                                              45   TiO2-c | TiO2-mp
# 2                                              10   TiO2-c | TiO2-mp
# 3                                              10             TiO2-c
# 4                                              10             TiO2-c
# ...                                           ...                ...
# 7196                                 100.0 >> 2.0   TiO2-c | TiO2-mp
# 7197                                  0.0 >> 10.0   TiO2-c | TiO2-mp
# 7198                                 100.0 >> 2.0   TiO2-c | TiO2-mp
# 7199                                 100.0 >> 2.0   TiO2-c | TiO2-mp
# 7200                                           50   TiO2-c | TiO2-mp
#
#      ETL_thickness HTL_stack_sequence  HTL_additives_compounds  \
# 0      nan | 195.0       Spiro-MeOTAD             Li-TFSI; TBP
# 1     50.0 | 300.0       Spiro-MeOTAD             Li-TFSI; TBP
# 2      100.0 | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 3               40       Spiro-MeOTAD             Li-TFSI; TBP
# 4               40       Spiro-MeOTAD             Li-TFSI; TBP
# ...            ...                ...                      ...
# 7196     nan | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 7197     nan | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 7198     nan | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 7199     nan | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 7200    50.0 | nan       Spiro-MeOTAD      FK209; Li-TFSI; TBP
#
#      Perovskite_deposition_solvents JV_default_PCE
# 0                         DMF; DMSO           7.80
# 1                              DMSO          16.40
# 2                               DMF           1.08
# 3                         DMF; DMSO          14.86
# 4                         DMF; DMSO          17.39
# ...                             ...            ...
# 7196                 DMF >> Toluene           9.61
# 7197                 DMF >> Toluene           7.50
# 7198                 DMF >> Toluene           9.80
# 7199                 DMF >> Toluene           7.78
# 7200                      DMF; DMSO           3.20
#
# [7201 rows x 26 columns]

# %%
data = data.fillna(0)
data
# Out:
#               a1   a2   a3   a4 a1_coefficients a2_coefficients  \
# 0          (Ada)   FA    0    0               2               2
# 1     (AVA) | MA    0    0    0           2 | 1               0
# 2          (BdA)    0    0    0               1               0
# 3          (BEA)   MA    0    0             0.5               3
# 4          (BEA)   Cs   FA   MA             0.5            0.15
# ...          ...  ...  ...  ...             ...             ...
# 7196     MA | MA    0    0    0           1 | 1               0
# 7197     MA | MA    0    0    0           1 | 1               0
# 7198     MA | MA    0    0    0           1 | 1               0
# 7199     MA | MA    0    0    0           1 | 1               0
# 7200          PA    0    0    0               2               0
#
#      a3_coefficients  a4_coefficients       b1 b2  ... c2_coefficients  \
# 0                  0             0.00       Pb  0  ...               0
# 1                  0             0.00  Pb | Pb  0  ...               0
# 2                  0             0.00       Pb  0  ...               0
# 3                  0             0.00       Pb  0  ...               0
# 4               2.36             0.48       Pb  0  ...            0.83
# ...              ...              ...      ... ..  ...             ...
# 7196               0             0.00  Pb | Pb  0  ...               0
# 7197               0             0.00  Pb | Pb  0  ...               0
# 7198               0             0.00  Pb | Pb  0  ...               0
# 7199               0             0.00  Pb | Pb  0  ...               0
# 7200               0             0.00       Pb  0  ...               0
#
#       c3_coefficients Perovskite_deposition_thermal_annealing_temperature  \
# 0                 0.0                                       120.0; 150.0
# 1                 0.0                                                100
# 2                 0.0                                                 90
# 3                 0.0                                                100
# 4                 0.0                                                100
# ...               ...                                                ...
# 7196              0.0                                         100 >> 100
# 7197              0.0                                          25 >> 100
# 7198              0.0                                         100 >> 100
# 7199              0.0                                         100 >> 100
# 7200              0.0                                                105
#
#      Perovskite_deposition_thermal_annealing_time ETL_stack_sequence  \
# 0                                      20.0; 10.0   TiO2-c | TiO2-mp
# 1                                              45   TiO2-c | TiO2-mp
# 2                                              10   TiO2-c | TiO2-mp
# 3                                              10             TiO2-c
# 4                                              10             TiO2-c
# ...                                           ...                ...
# 7196                                 100.0 >> 2.0   TiO2-c | TiO2-mp
# 7197                                  0.0 >> 10.0   TiO2-c | TiO2-mp
# 7198                                 100.0 >> 2.0   TiO2-c | TiO2-mp
# 7199                                 100.0 >> 2.0   TiO2-c | TiO2-mp
# 7200                                           50   TiO2-c | TiO2-mp
#
#      ETL_thickness HTL_stack_sequence  HTL_additives_compounds  \
# 0      nan | 195.0       Spiro-MeOTAD             Li-TFSI; TBP
# 1     50.0 | 300.0       Spiro-MeOTAD             Li-TFSI; TBP
# 2      100.0 | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 3               40       Spiro-MeOTAD             Li-TFSI; TBP
# 4               40       Spiro-MeOTAD             Li-TFSI; TBP
# ...            ...                ...                      ...
# 7196     nan | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 7197     nan | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 7198     nan | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 7199     nan | nan       Spiro-MeOTAD             Li-TFSI; TBP
# 7200    50.0 | nan       Spiro-MeOTAD      FK209; Li-TFSI; TBP
#
#      Perovskite_deposition_solvents JV_default_PCE
# 0                         DMF; DMSO           7.80
# 1                              DMSO          16.40
# 2                               DMF           1.08
# 3                         DMF; DMSO          14.86
# 4                         DMF; DMSO          17.39
# ...                             ...            ...
# 7196                 DMF >> Toluene           9.61
# 7197                 DMF >> Toluene           7.50
# 7198                 DMF >> Toluene           9.80
# 7199                 DMF >> Toluene           7.78
# 7200                      DMF; DMSO           3.20
#
# [7201 rows x 26 columns]

# %%
# 显示所有列
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#               a1   a2   a3   a4 a1_coefficients a2_coefficients  \
# 0          (Ada)   FA    0    0               2               2
# 1     (AVA) | MA    0    0    0           2 | 1               0
# 2          (BdA)    0    0    0               1               0
# 3          (BEA)   MA    0    0             0.5               3
# 4          (BEA)   Cs   FA   MA             0.5            0.15
# ...          ...  ...  ...  ...             ...             ...
# 7196     MA | MA    0    0    0           1 | 1               0
# 7197     MA | MA    0    0    0           1 | 1               0
# 7198     MA | MA    0    0    0           1 | 1               0
# 7199     MA | MA    0    0    0           1 | 1               0
# 7200          PA    0    0    0               2               0
#
#      a3_coefficients  a4_coefficients       b1 b2 b1_coefficients  \
# 0                  0             0.00       Pb  0               3
# 1                  0             0.00  Pb | Pb  0           1 | 1
# 2                  0             0.00       Pb  0               1
# 3                  0             0.00       Pb  0               3
# 4               2.36             0.48       Pb  0               3
# ...              ...              ...      ... ..             ...
# 7196               0             0.00  Pb | Pb  0           1 | 1
# 7197               0             0.00  Pb | Pb  0           1 | 1
# 7198               0             0.00  Pb | Pb  0           1 | 1
# 7199               0             0.00  Pb | Pb  0           1 | 1
# 7200               0             0.00       Pb  0               1
#
#       b2_coefficients     c1  c2 c3 c1_coefficients c2_coefficients  \
# 0                 0.0      I   0  0              10               0
# 1                 0.0  I | I   0  0           4 | 3               0
# 2                 0.0      I   0  0               4               0
# 3                 0.0      I   0  0              10               0
# 4                 0.0     Br   I  0             1.7            0.83
# ...               ...    ...  .. ..             ...             ...
# 7196              0.0  I | I   0  0           3 | 3               0
# 7197              0.0  I | I   0  0           3 | 3               0
# 7198              0.0  I | I   0  0           3 | 3               0
# 7199              0.0  I | I   0  0           3 | 3               0
# 7200              0.0      I   0  0               4               0
#
#       c3_coefficients Perovskite_deposition_thermal_annealing_temperature  \
# 0                 0.0                                       120.0; 150.0
# 1                 0.0                                                100
# 2                 0.0                                                 90
# 3                 0.0                                                100
# 4                 0.0                                                100
# ...               ...                                                ...
# 7196              0.0                                         100 >> 100
# 7197              0.0                                          25 >> 100
# 7198              0.0                                         100 >> 100
# 7199              0.0                                         100 >> 100
# 7200              0.0                                                105
#
#      Perovskite_deposition_thermal_annealing_time ETL_stack_sequence  \
# 0                                      20.0; 10.0   TiO2-c | TiO2-mp
# 1                                              45   TiO2-c | TiO2-mp
# 2                                              10   TiO2-c | TiO2-mp
# 3                                              10             TiO2-c
# 4                                              10             TiO2-c
# ...                                           ...                ...
# 7196                                 100.0 >> 2.0   TiO2-c | TiO2-mp
# 7197                                  0.0 >> 10.0   TiO2-c | TiO2-mp
# 7198                                 100.0 >> 2.0   TiO2-c | TiO2-mp
# 7199                                 100.0 >> 2.0   TiO2-c | TiO2-mp
# 7200                                           50   TiO2-c | TiO2-mp
#
#      ETL_thickness HTL_stack_sequence HTL_additives_compounds  \
# 0      nan | 195.0       Spiro-MeOTAD            Li-TFSI; TBP
# 1     50.0 | 300.0       Spiro-MeOTAD            Li-TFSI; TBP
# 2      100.0 | nan       Spiro-MeOTAD            Li-TFSI; TBP
# 3               40       Spiro-MeOTAD            Li-TFSI; TBP
# 4               40       Spiro-MeOTAD            Li-TFSI; TBP
# ...            ...                ...                     ...
# 7196     nan | nan       Spiro-MeOTAD            Li-TFSI; TBP
# 7197     nan | nan       Spiro-MeOTAD            Li-TFSI; TBP
# 7198     nan | nan       Spiro-MeOTAD            Li-TFSI; TBP
# 7199     nan | nan       Spiro-MeOTAD            Li-TFSI; TBP
# 7200    50.0 | nan       Spiro-MeOTAD     FK209; Li-TFSI; TBP
#
#      Perovskite_deposition_solvents  JV_default_PCE
# 0                         DMF; DMSO            7.80
# 1                              DMSO           16.40
# 2                               DMF            1.08
# 3                         DMF; DMSO           14.86
# 4                         DMF; DMSO           17.39
# ...                             ...             ...
# 7196                 DMF >> Toluene            9.61
# 7197                 DMF >> Toluene            7.50
# 7198                 DMF >> Toluene            9.80
# 7199                 DMF >> Toluene            7.78
# 7200                      DMF; DMSO            3.20
#
# [7201 rows x 26 columns]

# %%
# ionic radius

Ada
